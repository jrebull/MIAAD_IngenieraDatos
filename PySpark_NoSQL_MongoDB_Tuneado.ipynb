# %% [markdown]
# <a href="https://colab.research.google.com/github/jrebull/MIAAD_IngenieraDatos/blob/main/PySpark_NoSQL_MongoDB_Tuneado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PySpark con MongoDB Atlas**
#
#
#
# ---
#
# Programa: Maestría en Inteligencia Artificial y Analítica de Datos
#
# Materia: Ingeniería de Datos Avanzada
#
# Fecha: 11/Octubre/2025
#
# Profesor: Dr. Vicente García Jiménez
#
# ---
#
#
#
# **Objetivo de la Sesión:**
#
# Conectar PySpark con MongoDB Atlas para leer, transformar, agregar y escribir datos desde/ hacia una colección NoSQL, aplicando buenas prácticas de configuración, seguridad y desempeño en Google Colab.
#
#
#
# ---
#
#
# **Objetivos específicos**
#
# - Configurar SparkSession en Colab con el MongoDB Spark Connector (V2) usando mongodb+srv.
#
# - Leer una colección de Atlas como DataFrame, inspeccionar esquema y muestras.
#
# - Realizar transformaciones y Acciones.
#
# - PySpark y SQL.
#
#
# ---

# %% [markdown]
# ## **Configurar SparkSession en Colab con el MongoDB Spark Connector (V2) usando mongodb+srv**
#
# Para poder crear un SparkSession es necesario primer tener instalado PySpark. Asimismo, revisar en tu cuenta de MongoDB Atlas la conexión para obtener la cadena que te permitirá realizar poder acceder a la base de datos que está en la nube.

# %% [markdown]
# ### PySpark
#
# Para lograr crear una SparkSession es necesario saber si está instalado pyspark. Para ello ejecutaremos `!pyspark --version`. En el caso de tener instalado PySpark deberás instalarlo ejecutando `!pip install pyspark`

# %%
# Verificar la versión e imprimir
print("\nVersión de PySpark:")
# !pyspark --version
# Out:
# Versión de PySpark:
# WARNING: Using incubator modules: jdk.incubator.vector
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /___/ .__/\_,_/_/ /_/\_\   version 4.0.2
#       /_/
#
# Using Scala version 2.13.16, OpenJDK 64-Bit Server VM, 17.0.18
# Branch HEAD
# Compiled by user runner on 2026-02-02T08:08:13Z
# Revision 7cc3b9bcdaab8c923f23cdbc9ce922530e1becf1
# Url https://github.com/apache/spark
# Type --help for more information.

# %% [markdown]
# ### Cadena de Conexión SRV: MongoDB Atlas
#
# Para poder conectarte al clúster en Atlas, es necesario que tengas las cadena de conexión SRV. Para ello, deberás acceder a tu cuenta de MongoDB, la cual creaste previamente en otra sesión de esta clase.
#
# Una vez en tu página de MongoDB Atlas ubica tu proyecto. En nuestro caso se llama Project 0. Una vez seleccionado aparecerá el Overview en el que podrás ver el nombre del Clúster que creamos y que por default fue asignado el nombre de **Cluster0**. Selecciona **Connect**, el cual se encuentra a la izquierda de *Edit Configuration*.

# %% [markdown]
# Una vez que seleccionaste **Connect**, aparecerá otra venta con las diferentes opciones para poder conectar tu clúster con diferentes conectores o clientes.

# %% [markdown]
# Elige la opción de **Drivers**, la cual te mostrará otra ventana. Observa en la imagen el punto *3. Add your connection string in your application*, el cual contiene la cadena de conexión necesaria para realizar la conexión con PySpark en Google Colab.
#
#
# La cadena tiene la siguiente forma `mongodb+srv://<db_username>:<db_password>@cluster0.cujjqxq.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0`
#
# Observa que cadena no tiene nombre de usuario *db_user*. Seguramente, tu cadena tendrá el nombre de usuario que tú elegiste. Asimismo, como menciona en esta misma ventana, es importante que agregues tu *password* en *db_password*.

# %% [markdown]
# **¿Para qué sirve la cadena de conexión SRV?**
#
# Para que tus aplicaciones/entornos (Colab + PySpark, scripts Python, MongoDB Compass, etc.) se autentiquen y conecten al clúster adecuado con configuración segura por defecto (TLS, réplicas, balanceo).

# %% [markdown]
# ## **SparkSession con el Conector de MongoDB**
#
# Como se vió en la sesión pasada, es necesario importar la biblioteca de Spark, y asì poder crear `SparkSession`, que es la puerta de entrada a la API DataFrame/SQL de Spark (la interfaz recomendada hoy).
#
# Recueda que:
#
# * Cuando se crea `SparkSession`es posible agregar configuraciones. En nuestro caso vamos a emplear la cadena SRV para conectarnos. Adicionalmente, agregaremos otras configuraciones para leer, escribir y finalmente para descargar el conector oficial para Spark  (*spark.jars.packages*) por medio de la cadena que contiene la coordenada a dicho paquete *org.mongodb.spark:mongo-spark-connector_2.12:10.5.0*.
#
# * Para poder realizar una modificación rápida a la cadena de conexión  vamos a crear una variable llamada MONGODB_URI que contendrá dicha cadena que usarémos para que PySpark sepa a qué clúster conectarse y cómo autenticarse.
#
# * En este ejemplo he usado mi propia cadena de conexión para el usario *new_user_miaad* con el password *miaad2025*.
#
# * También he creado una cadena para poder descargar el conector oficial para Spark. Esto no es necesario ya que lo puedes escribir directamente. Sin embargo, por claridad y sencillez he creado dicha variable llamada *mongo_connector_coords*

# %%
#@title Construir SparkSession con MongoDB Spark Connector (DataSource V2)
from pyspark.sql import SparkSession
from google.colab import userdata

# Leer desde Secrets
MONGODB_URI = userdata.get('MONGODB_URI')

# Cadena de Conexión
#MONGODB_URI = "mongodb+srv://rebull:miaad2026@cluster0.1pg8t1c.mongodb.net/?appName=Cluster0"

#Cadena de Coordenadas de Conector de MongoDB para Spark
#Descargará el conector
mongo_connector_coords = "org.mongodb.spark:mongo-spark-connector_2.13:10.5.0"

# Configurar Spark Session con el conector de MongoDB
spark = (SparkSession.builder
         .appName("PySpark-MongoDB-Colab")
         .config("spark.mongodb.read.connection.uri", MONGODB_URI)
         .config("spark.mongodb.write.connection.uri", MONGODB_URI)
         .config("spark.jars.packages", mongo_connector_coords)
         .getOrCreate())

# Obtener SparkContext
sc = spark.sparkContext

print(f"Spark Version: {spark.version}")
print(f"SparkContext creado exitosamente")
# Out:
# Spark Version: 4.0.2
# SparkContext creado exitosamente

# %% [markdown]
# ## Lectura desde MongoDB: sample_mflix
#
# En este ejercicio vamos a usar la base de datos *sample_mflix* y la colección *movies*. Leeremos la colección como DataFrame y contaremos el número de registros.
#
# Usaremos `spark.read`que contiene una serie de instrucciones para indicar el formato, nombre de la base de datos y la colección.

# %%
#@title Leer colección como DataFrame
df = (
    spark.read
    .format("mongodb")
    .option("database", "sample_mflix")
    .option("collection", "movies")
    .load()
)

print("Filas estimadas (lazy):", df.count())  # ejecuta una acción para materializar
df.printSchema()
df.show(5, truncate=False)
# Out:
# Filas estimadas (lazy): 21349
# root
#  |-- _id: string (nullable = true)
#  |-- awards: struct (nullable = true)
#  |    |-- wins: integer (nullable = true)
#  |    |-- nominations: integer (nullable = true)
#  |    |-- text: string (nullable = true)
#  |-- cast: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- countries: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- directors: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- fullplot: string (nullable = true)
#  |-- genres: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- imdb: struct (nullable = true)
#  |    |-- id: integer (nullable = true)
#  |    |-- rating: string (nullable = true)
#  |    |-- votes: string (nullable = true)
#  |-- languages: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- lastupdated: string (nullable = true)
#  |-- metacritic: integer (nullable = true)
#  |-- num_mflix_comments: integer (nullable = true)
#  |-- plot: string (nullable = true)
#  |-- poster: string (nullable = true)
#  |-- rated: string (nullable = true)
#  |-- released: timestamp (nullable = true)
#  |-- runtime: integer (nullable = true)
#  |-- title: string (nullable = true)
#  |-- tomatoes: struct (nullable = true)
#  |    |-- boxOffice: string (nullable = true)
#  |    |-- consensus: string (nullable = true)
#  |    |-- critic: struct (nullable = true)
#  |    |    |-- meter: integer (nullable = true)
#  |    |    |-- numReviews: integer (nullable = true)
#  |    |    |-- rating: double (nullable = true)
#  |    |-- dvd: timestamp (nullable = true)
#  |    |-- fresh: integer (nullable = true)
#  |    |-- lastUpdated: timestamp (nullable = true)
#  |    |-- production: string (nullable = true)
#  |    |-- rotten: integer (nullable = true)
#  |    |-- viewer: struct (nullable = true)
#  |    |    |-- meter: integer (nullable = true)
#  |    |    |-- numReviews: integer (nullable = true)
#  |    |    |-- rating: double (nullable = true)
#  |    |-- website: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- writers: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- year: string (nullable = true)
#
# +------------------------+---------------------+----------------------------------------------------------------------------+---------+--------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------+------------------+---------+-----------------------------+----------+------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------+------+-------------------+-------+-------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------+-----+-------------------------------------------------------------------------------------------------------------------------------------------+----+
# |_id                     |awards               |cast                                                                        |countries|directors           |fullplot                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |genres                   |imdb              |languages|lastupdated                  |metacritic|num_mflix_comments|plot                                                                                                                                                                                            |poster                                                                                                                                       |rated |released           |runtime|title                          |tomatoes                                                                                                                                       |type |writers                                                                                                                                    |year|
# +------------------------+---------------------+----------------------------------------------------------------------------+---------+--------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------+------------------+---------+-----------------------------+----------+------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------+------+-------------------+-------+-------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------+-----+-------------------------------------------------------------------------------------------------------------------------------------------+----+
# |573a1390f29313caabcd587d|{1, 0, 1 win.}       |[John McCann, James A. Marcus, Maggie Weston, Harry McCoy]                  |[USA]    |[Raoul Walsh]       |At 10 years old, Owens becomes a ragged orphan when his sainted mother dies. The Conways, who are next door neighbors, take Owen in, but the constant drinking by Jim soon puts Owen on the street. By 17, Owen learns that might is right. By 25, Owen is the leader of his own gang who spend most of their time gambling and drinking. But Marie comes into the gangster area of town and everything changes for Owen as he falls for Marie. But he cannot tell her so, so he comes to her settlement to find education and inspiration. But soon, his old way of life will rise to confront him again.|[Biography, Crime, Drama]|{5960, 6.8, 626}  |[English]|2015-08-14 01:28:18.957000000|NULL      |1                 |At 10 years old, Owens becomes a ragged orphan when his sainted mother dies. The Conways, who are next door neighbors, take Owen in, but the constant drinking by Jim soon puts Owen on the ... |https://m.media-amazon.com/images/M/MV5BNDkxZGU4NmMtODJlNy00YzA2LTg4ZGMtNGFlNzAyNzcxOTM1XkEyXkFqcGdeQXVyOTM3MjcyMjI@._V1_SY1000_SX677_AL_.jpg|PASSED|1915-09-13 00:00:00|72     |Regeneration                   |{NULL, NULL, {100, 5, 9.2}, 2001-11-27 00:00:00, 5, 2015-09-17 17:22:42, Fox Film Corporation, 0, {70, 395, 3.4}, NULL}                        |movie|[Owen Frawley Kildare (book), Raoul Walsh (adapted from the book: "My Mamie Rose"), Carl Harbaugh (adapted from the book: "My Mamie Rose")]|1915|
# |573a1391f29313caabcd6d40|{0, 1, 1 nomination.}|[Harold Lloyd, Roy Brooks, Mildred Davis, Wallace Howe]                     |[USA]    |[Hal Roach]         |After a long wait, a young doctor finally has a patient come to his office. She is a young woman whose father has brought her to be treated for sleep-walking, but the father becomes annoyed with the doctor, and takes his daughter away. Soon afterward, the young doctor shares in a drinking binge with another doctor who has built a still in his office. After a series of misadventures, the two of them wind up in the same hotel where the daughter and her father are staying, leading to some hazardous predicaments.                                                                        |[Comedy, Short]          |{11293, 7.0, 646} |[English]|2015-08-11 00:35:33.717000000|NULL      |1                 |A tipsy doctor encounters his patient sleepwalking on a building ledge, high above the street.                                                                                                  |https://m.media-amazon.com/images/M/MV5BODliMjc3ODctYjhlOC00MDM5LTgzNmUtMjQ1MmViNDQ0NzlhXkEyXkFqcGdeQXVyNTM3MDMyMDQ@._V1_SY1000_SX677_AL_.jpg|PASSED|1920-07-11 00:00:00|26     |High and Dizzy                 |{NULL, NULL, NULL, NULL, NULL, 2015-06-27 19:17:10, NULL, NULL, {70, 30, 3.4}, NULL}                                                           |movie|[Frank Terry (story), H.M. Walker (titles)]                                                                                                |1920|
# |573a1391f29313caabcd7472|{1, 0, 1 win.}       |[Rudolph Christians, Miss DuPont, Maude George, Mae Busch]                  |[USA]    |[Erich von Stroheim]|"Count" Karanzim, a Don Juan is with his cousins in Monte Carlo, living from faked money and the money he gets from rich ladies, who are attracted by his charmes and his title or his militaristic and aristocratic behaviour. He tries to have success with Mrs Hughes, the wife of the new US ambassador.                                                                                                                                                                                                                                                                                              |[Drama]                  |{13140, 7.3, 1777}|[English]|2015-09-05 00:00:37.817000000|NULL      |0                 |A con artist masquerades a Russian nobility and attempts to seduce the wife of an American diplomat.                                                                                            |https://m.media-amazon.com/images/M/MV5BMTk2NDkxMTY1Nl5BMl5BanBnXkFtZTgwNDI1NDU5MTE@._V1_SY1000_SX677_AL_.jpg                                |NULL  |1922-01-11 00:00:00|117    |Foolish Wives                  |{NULL, NULL, {89, 9, 9.0}, 2000-09-19 00:00:00, 8, 2015-09-15 17:02:32, Universal Pictures, 1, {77, 1079, 3.7}, NULL}                          |movie|[Erich von Stroheim (story), Marian Ainslee (titles), Walter Anthony (titles)]                                                             |1922|
# |573a1390f29313caabcd516c|{1, 0, 1 win.}       |[Stanley Hunt, Sarah Constance Smith Hunt, Mrs. George Walkus, Paddy 'Malid]|[USA]    |[Edward S. Curtis]  |NULL                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |[Drama, History]         |{4150, 5.8, 223}  |[English]|2015-09-16 12:11:37.770000000|NULL      |1                 |Original advertising for the film describes it as a drama of primitive life on the shores of the North Pacific...                                                                               |https://m.media-amazon.com/images/M/MV5BMjE3MjAyNzM5NV5BMl5BanBnXkFtZTgwMjA5OTg5NjE@._V1_SY1000_SX677_AL_.jpg                                |NULL  |1914-12-07 00:00:00|65     |In the Land of the Head Hunters|{NULL, NULL, NULL, 2000-08-15 00:00:00, NULL, 2015-08-18 19:21:12, World Film Corporation, NULL, {18, 64, 2.7}, http://www.milestonefilms.com/}|movie|[Edward S. Curtis (story)]                                                                                                                 |1914|
# |573a1390f29313caabcd63d6|{1, 0, 1 win.}       |[Tula Belle, Robin Macdougall, Edwin E. Reed, Emma Lowry]                   |[USA]    |[Maurice Tourneur]  |Two peasant children, Mytyl and Tyltyl, are led by Berylune, a fairy, to search for the Blue Bird of Happiness. Berylune gives Tyltyl a cap with a diamond setting, and when Tyltyl turns the diamond, the children become aware of and conversant with the souls of a Dog and Cat, as well as of Fire, Water, Bread, Light, and other presumably inanimate things. The troupe thus sets off to find the elusive Blue Bird of Happiness.                                                                                                                                                                  |[Fantasy]                |{8891, 6.6, 446}  |[English]|2015-07-20 00:32:04.810000000|NULL      |0                 |Two peasant children, Mytyl and Tyltyl, are led by Berylune, a fairy, to search for the Blue Bird of Happiness. Berylune gives Tyltyl a cap with a diamond setting, and when Tyltyl turns the...|https://m.media-amazon.com/images/M/MV5BMjNlMThmNzItMTZlMS00YzJkLTk1MzktYzIyMzllOGFmZmRlXkEyXkFqcGdeQXVyMzE0MjY5ODA@._V1_SY1000_SX677_AL_.jpg|NULL  |1918-03-31 00:00:00|75     |The Blue Bird                  |{NULL, NULL, NULL, 2005-09-06 00:00:00, NULL, 2015-08-21 18:10:22, NULL, NULL, {60, 607, 3.6}, NULL}                                           |movie|[Maurice Maeterlinck (play), Charles Maigne]                                                                                               |1918|
# +------------------------+---------------------+----------------------------------------------------------------------------+---------+--------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------+------------------+---------+-----------------------------+----------+------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------+------+-------------------+-------+-------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------+-----+-------------------------------------------------------------------------------------------------------------------------------------------+----+
# only showing top 5 rows

# %% [markdown]
# Podemos imprimir también el tipo de datos del DataFrame

# %%
df.dtypes
# Out:
# [('_id', 'string'),
#  ('awards', 'struct<wins:int,nominations:int,text:string>'),
#  ('cast', 'array<string>'),
#  ('countries', 'array<string>'),
#  ('directors', 'array<string>'),
#  ('fullplot', 'string'),
#  ('genres', 'array<string>'),
#  ('imdb', 'struct<id:int,rating:string,votes:string>'),
#  ('languages', 'array<string>'),
#  ('lastupdated', 'string'),
#  ('metacritic', 'int'),
#  ('num_mflix_comments', 'int'),
#  ('plot', 'string'),
#  ('poster', 'string'),
#  ('rated', 'string'),
#  ('released', 'timestamp'),
#  ('runtime', 'int'),
#  ('title', 'string'),
#  ('tomatoes',
#   'struct<boxOffice:string,consensus:string,critic:struct<meter:int,numReviews:int,rating:double>,dvd:timestamp,fresh:int,lastUpdated:timestamp,production:string,rotten:int,viewer:struct<meter:int,numReviews:int,rating:double>,website:string>'),
#  ('type', 'string'),
#  ('writers', 'array<string>'),
#  ('year', 'string')]

# %% [markdown]
# ## ¿Un DataFrame es un RDD?
#
# Cuando lees una colección de MongoDB Atlas con el conector `spark.read` obtienes un DataFrame. En PySpark, un DataFrame es (conceptualmente) un Dataset[Row] con esquema y un plan lógico que Spark optimiza (Catalyst/Tungsten).
#
# Sí existe un RDD "debajo", pero en realidad existe dicho RDD cuando ejecutas instrucciones de SQL sobre dicho DataFrame. Por lo tanto, podríamos decir que no es RDD directo.
#
# Es posible convertir el DataFrame a RDD directo. Sin embargo, cuando se hace esto no puedes ejecutar instrucciones SQL sobre el nuevo RDD.

# %%
#@title Convertir DataFrame a RDD
rdd = df.rdd
print(f"\nRDD creado con {rdd.count()} elementos")

#Si deseas imprimir todo el contenido del RDD puedes usar la
#instrucción collect. Sin embargo imprimirá todo el contenido.

rdd.collect()
# Out:
# RDD creado con 21349 elementos
# [Row(_id='573a1390f29313caabcd587d', awards=Row(wins=1, nominations=0, text='1 win.'), cast=['John McCann', 'James A. Marcus', 'Maggie Weston', 'Harry McCoy'], countries=['USA'], directors=['Raoul Walsh'], fullplot='At 10 years old, Owens becomes a ragged orphan when his sainted mother dies. The Conways, who are next door neighbors, take Owen in, but the constant drinking by Jim soon puts Owen on the street. By 17, Owen learns that might is right. By 25, Owen is the leader of his own gang who spend most of their time gambling and drinking. But Marie comes into the gangster area of town and everything changes for Owen as he falls for Marie. But he cannot tell her so, so he comes to her settlement to find education and inspiration. But soon, his old way of life will rise to confront him again.', genres=['Biography', 'Crime', 'Drama'], imdb=Row(id=5960, rating='6.8', votes='626'), languages=['English'], lastupdated='2015-08-14 01:28:18.957000000', metacritic=None, num_mflix_comments=1, plot='At 10 years old, Owens becomes a ragged orphan when his sainted mother dies. The Conways, who are next door neighbors, take Owen in, but the constant drinking by Jim soon puts Owen on the ...', poster='https://m.media-amazon.com/images/M/MV5BNDkxZGU4NmMtODJlNy00YzA2LTg4ZGMtNGFlNzAyNzcxOTM1XkEyXkFqcGdeQXVyOTM3MjcyMjI@._V1_SY1000_SX677_AL_.jpg', rated='PASSED', released=datetime.datetime(1915, 9, 13, 0, 0), runtime=72, title='Regeneration', tomatoes=Row(boxOffice=None, consensus=None, critic=Row(meter=100, numReviews=5, rating=9.2), dvd=datetime.datetime(2001, 11, 27, 0, 0), fresh=5, lastUpdated=datetime.datetime(2015, 9, 17, 17, 22, 42), production='Fox Film Corporation', rotten=0, viewer=Row(meter=70, numReviews=395, rating=3.4), website=None), type='movie', writers=['Owen Frawley Kildare (book)', 'Raoul Walsh (adapted from the book: "My Mamie Rose")', 'Carl Harbaugh (adapted from the book: "My Mamie Rose")'], year='1915'),
#  Row(_id='573a1391f29313caabcd6d40', awards=Row(wins=0, nominations=1, text='1 nomination.'), cast=['Harold Lloyd', 'Roy Brooks', 'Mildred Davis', 'Wallace Howe'], countries=['USA'], directors=['Hal Roach'], fullplot='After a long wait, a young doctor finally has a patient come to his office. She is a young woman whose father has brought her to be treated for sleep-walking, but the father becomes annoyed with the doctor, and takes his daughter away. Soon afterward, the young doctor shares in a drinking binge with another doctor who has built a still in his office. After a series of misadventures, the two of them wind up in the same hotel where the daughter and her father are staying, leading to some hazardous predicaments.', genres=['Comedy', 'Short'], imdb=Row(id=11293, rating='7.0', votes='646'), languages=['English'], lastupdated='2015-08-11 00:35:33.717000000', metacritic=None, num_mflix_comments=1, plot='A tipsy doctor encounters his patient sleepwalking on a building ledge, high above the street.', poster='https://m.media-amazon.com/images/M/MV5BODliMjc3ODctYjhlOC00MDM5LTgzNmUtMjQ1MmViNDQ0NzlhXkEyXkFqcGdeQXVyNTM3MDMyMDQ@._V1_SY1000_SX677_AL_.jpg', rated='PASSED', released=datetime.datetime(1920, 7, 11, 0, 0), runtime=26, title='High and Dizzy', tomatoes=Row(boxOffice=None, consensus=None, critic=None, dvd=None, fresh=None, lastUpdated=datetime.datetime(2015, 6, 27, 19, 17, 10), production=None, rotten=None, viewer=Row(meter=70, numReviews=30, rating=3.4), website=None), type='movie', writers=['Frank Terry (story)', 'H.M. Walker (titles)'], year='1920'),
#  Row(_id='573a1391f29313caabcd7472', awards=Row(wins=1, nominations=0, text='1 win.'), cast=['Rudolph Christians', 'Miss DuPont', 'Maude George', 'Mae Busch'], countries=['USA'], directors=['Erich von Stroheim'], fullplot='"Count" Karanzim, a Don Juan is with his cousins in Monte Carlo, living from faked money and the money he gets from rich ladies, who are attracted by his charmes and his title or his militaristic and aristocratic behaviour. He tries to have success with Mrs Hughes, the wife of the new US ambassador.', genres=['Drama'], imdb=Row(id=13140, rating='7.3', votes='1777'), languages=['English'], lastupdated='2015-09-05 00:00:37.817000000', metacritic=None, num_mflix_comments=0, plot='A con artist masquerades a Russian nobility and attempts to seduce the wife of an American diplomat.', poster='https://m.media-amazon.com/images/M/MV5BMTk2NDkxMTY1Nl5BMl5BanBnXkFtZTgwNDI1NDU5MTE@._V1_SY1000_SX677_AL_.jpg', rated=None, released=datetime.datetime(1922, 1, 11, 0, 0), runtime=117, title='Foolish Wives', tomatoes=Row(boxOffice=None, consensus=None, critic=Row(meter=89, numReviews=9, rating=9.0), dvd=datetime.datetime(2000, 9, 19, 0, 0), fresh=8, lastUpdated=datetime.datetime(2015, 9, 15, 17, 2, 32), production='Universal Pictures', rotten=1, viewer=Row(meter=77, numReviews=1079, rating=3.7), website=None), type='movie', writers=['Erich von Stroheim (story)', 'Marian Ainslee (titles)', 'Walter Anthony (titles)'], year='1922'),
#  Row(_id='573a1390f29313caabcd516c', awards=Row(wins=1, nominations=0, text='1 win.'), cast=['Stanley Hunt', 'Sarah Constance Smith Hunt', 'Mrs. George Walkus', "Paddy 'Malid"], countries=['USA'], directors=['Edward S. Curtis'], fullplot=None, genres=['Drama', 'History'], imdb=Row(id=4150, rating='5.8', votes='223'), languages=['English'], lastupdated='2015-09-16 12:11:37.770000000', metacritic=None, num_mflix_comments=1, plot='Original advertising for the film describes it as a drama of primitive life on the shores of the North Pacific...', poster='https://m.media-amazon.com/images/M/MV5BMjE3MjAyNzM5NV5BMl5BanBnXkFtZTgwMjA5OTg5NjE@._V1_SY1000_SX677_AL_.jpg', rated=None, released=datetime.datetime(1914, 12, 7, 0, 0), runtime=65, title='In the Land of the Head Hunters', tomatoes=Row(boxOffice=None, consensus=None, critic=None, dvd=datetime.datetime(2000, 8, 15, 0, 0), fresh=None, lastUpdated=datetime.datetime(2015, 8, 18, 19, 21, 12), production='World Film Corporation', rotten=None, viewer=Row(meter=18, numReviews=64, rating=2.7), website='http://www.milestonefilms.com/'), type='movie', writers=['Edward S. Curtis (story)'], year='1914'),
#  Row(_id='573a1390f29313caabcd63d6', awards=Row(wins=1, nominations=0, text='1 win.'), cast=['Tula Belle', 'Robin Macdougall', 'Edwin E. Reed', 'Emma Lowry'], countries=['USA'], directors=['Maurice Tourneur'], fullplot='Two peasant children, Mytyl and Tyltyl, are led by Berylune, a fairy, to search for the Blue Bird of Happiness. Berylune gives Tyltyl a cap with a diamond setting, and when Tyltyl turns the diamond, the children become aware of and conversant with the souls of a Dog and Cat, as well as of Fire, Water, Bread, Light, and other presumably inanimate things. The troupe thus sets off to find the elusive Blue Bird of Happiness.', genres=['Fantasy'], imdb=Row(id=8891, rating='6.6', votes='446'), languages=['English'], lastupdated='2015-07-20 00:32:04.810000000', metacritic=None, num_mflix_comments=0, plot='Two peasant children, Mytyl and Tyltyl, are led by Berylune, a fairy, to search for the Blue Bird of Happiness. Berylune gives Tyltyl a cap with a diamond setting, and when Tyltyl turns the...', poster='https://m.media-amazon.com/images/M/MV5BMjNlMThmNzItMTZlMS00YzJkLTk1MzktYzIyMzllOGFmZmRlXkEyXkFqcGdeQXVyMzE0MjY5ODA@._V1_SY1000_SX677_AL_.jpg', rated=None, released=datetime.datetime(1918, 3, 31, 0, 0), runtime=75, title='The Blue Bird', tomatoes=Row(boxOffice=None, consensus=None, critic=None, dvd=datetime.datetime(2005, 9, 6, 0, 0), fresh=None, lastUpdated=datetime.datetime(2015, 8, 21, 18, 10, 22), production=None, rotten=None, viewer=Row(meter=60, numReviews=607, rating=3.6), website=None), type='movie', writers=['Maurice Maeterlinck (play)', 'Charles Maigne'], year='1918'),
#  Row(_id='573a1391f29313caabcd71f5', awards=Row(wins=0, nominations=1, text='1 nomination.'), cast=['Harold Lloyd', 'Mildred Davis', 'Anna Mae Bilson'], countries=['USA'], directors=['Fred C. Newmeyer', 'Hal Roach'], fullplot="Mary is looking after a young child whose parents have little time for her. So, when Mary travels home to meet her childhood sweetheart, she takes the child with her. Meanwhile, her boyfriend has a mishap on the road, and is tricked out of his money by a tramp. When the tramp then hitches a ride on a train, the boyfriend does so as well. At the station, he meets Mary and the child, and they plan to re-board the train together. But difficulties arise when Mary sees her boss boarding the same train - and there is also the problem that her boyfriend doesn't have a ticket.", genres=['Comedy', 'Short'], imdb=Row(id=12512, rating='6.8', votes='489'), languages=['English'], lastupdated='2015-06-25 00:02:16.613000000', metacritic=None, num_mflix_comments=0, plot='A young man, unaccustomed to children, must accompany a young girl on a train trip.', poster='https://m.media-amazon.com/images/M/MV5BYjgzYzY1NjEtYWQxZS00ZjA4LWJlYmQtYzRjNTg3NjUwNDRlXkEyXkFqcGdeQXVyMjUxODE0MDY@._V1_SY1000_SX677_AL_.jpg', rated='PASSED', released=datetime.datetime(1921, 3, 27, 0, 0), runtime=35, title='Now or Never', tomatoes=Row(boxOffice=None, consensus=None, critic=None, dvd=None, fresh=None, lastUpdated=datetime.datetime(2015, 7, 16, 17, 59, 55), production=None, rotten=None, viewer=Row(meter=None, numReviews=3, rating=3.8), website=None), type='movie', writers=['H.M. Walker (titles)', 'Sam Taylor (scenario)'], year='1921'),
#  Row(_id='573a1390f29313caabcd446f', awards=Row(wins=1, nominations=0, text='1 win.'), cast=['Frank Powell', 'Grace Henderson', 'James Kirkwood', 'Linda Arvidson'], countries=['USA'], directors=['D.W. Griffith'], fullplot="A greedy tycoon decides, on a whim, to corner the world market in wheat. This doubles the price of bread, forcing the grain's producers into charity lines and further into poverty. The film continues to contrast the ironic differences between the lives of those who work to grow the wheat and the life of the man who dabbles in its sale for profit.", genres=['Short', 'Drama'], imdb=Row(id=832, rating='6.6', votes='1375'), languages=['English'], lastupdated='2015-08-13 00:46:30.660000000', metacritic=None, num_mflix_comments=1, plot="A greedy tycoon decides, on a whim, to corner the world market in wheat. This doubles the price of bread, forcing the grain's producers into charity lines and further into poverty. The film...", poster=None, rated='G', released=datetime.datetime(1909, 12, 13, 0, 0), runtime=14, title='A Corner in Wheat', tomatoes=Row(boxOffice=None, consensus=None, critic=None, dvd=None, fresh=None, lastUpdated=datetime.datetime(2015, 5, 11, 18, 36, 53), production=None, rotten=None, viewer=Row(meter=73, numReviews=109, rating=3.6), website=None), type='movie', writers=None, year='1909'),
#  Row(_id='573a1391f29313caabcd68d0', awards=Row(wins=0, nominations=1, text='1 nomination.'), cast=['Harold Lloyd', 'Mildred Davis', "'Snub' Pollard", 'Peggy Cartwright'], countries=['USA'], directors=['Alfred J. Goulding', 'Hal Roach'], fullplot="As a penniless man worries about how he will manage to eat, he is joined by a young waif and her dog, who are in the same predicament. Meanwhile, across town a dishonest lawyer is working with a gang of criminals, trying to swindle an innocent young heiress out of her inheritance. As the heiress is on her way home from the lawyer's office, she notices the young man and the waif in the midst of their latest problem with the authorities, and she rescues them. Later on, the young man will have an unexpected opportunity to repay her for her kindness.", genres=['Comedy', 'Short', 'Action'], imdb=Row(id=10146, rating='7.0', votes='639'), languages=['English'], lastupdated='2015-04-17 00:16:14.220000000', metacritic=None, num_mflix_comments=0, plot='A penniless young man tries to save an heiress from kidnappers and help her secure her inheritance.', poster='https://m.media-amazon.com/images/M/MV5BNzE1OWRlNDgtMTllNi00NTZiLWIyNTktYTk0MDY1ZWUwYTc5XkEyXkFqcGdeQXVyMjUxODE0MDY@._V1_SY1000_SX677_AL_.jpg', rated='TV-G', released=datetime.datetime(1919, 12, 28, 0, 0), runtime=22, title='From Hand to Mouth', tomatoes=Row(boxOffice=None, consensus=None, critic=None, dvd=None, fresh=None, lastUpdated=datetime.datetime(2015, 8, 21, 18, 45, 11), production='Pathè Exchange', rotten=None, viewer=Row(meter=55, numReviews=71, rating=3.3), website=None), type='movie', writers=['H.M. Walker (titles)'], year='1919'),
#  Row(_id='573a1391f29313caabcd6f98', awards=Row(wins=0, nominations=2, text='2 nominations.'), cast=['Lon Chaney', 'Leatrice Joy', 'John Bowers', 'Hardee Kirkland'], countries=['USA'], directors=['Wallace Worsley'], fullplot="A secret society holds a meeting to determine what to do about a powerful and dangerous man whom they have been studying closely for the past three months. They all agree that he deserves to die. Two of the members, Farallone and Forrest, are both in love with Lilith, the group's only female member. But Lilith accepts neither of them, preferring to devote herself to the group's cause. When the group meets again and deals cards to all the members, Forrest draws the ace of hearts, meaning that he will be the one to carry out the assassination. Lilith then suddenly agrees to marry him, in order to give him courage. But after their first night together, both of them begin to feel differently about what they have planned.", genres=['Crime', 'Drama', 'Mystery'], imdb=Row(id=11904, rating='7.0', votes='798'), languages=None, lastupdated='2015-07-20 00:01:29.560000000', metacritic=None, num_mflix_comments=1, plot='A romantic rivalry among members of a secret society becomes even tenser when one of the men is assigned to carry out an assassination.', poster='https://m.media-amazon.com/images/M/MV5BMTkwOTUyNDk1N15BMl5BanBnXkFtZTYwODI3MzI3._V1_SY1000_SX677_AL_.jpg', rated='PASSED', released=datetime.datetime(1924, 4, 4, 0, 0), runtime=75, title='The Ace of Hearts', tomatoes=Row(boxOffice=None, consensus=None, critic=None, dvd=None, fresh=None, lastUpdated=datetime.datetime(2015, 4, 28, 19, 29, 23), production=None, rotten=None, viewer=Row(meter=68, numReviews=377, rating=3.5), website=None), type='movie', writers=['Gouverneur Morris (by)', 'Ruth Wightman (scenario)'], year='1921'),
#  Row(_id='573a1390f29313caabcd42e8', awards=Row(wins=1, nominations=0, text='1 win.'), cast=['A.C. Abadie', "Gilbert M. 'Broncho Billy' Anderson", 'George Barnes', 'Justus D. Barnes'], countries=['USA'], directors=['Edwin S. Porter'], fullplot="Among the earliest existing films in American cinema - notable as the first film that presented a narrative story to tell - it depicts a group of cowboy outlaws who hold up a train and rob the passengers. They are then pursued by a Sheriff's posse. Several scenes have color included - all hand tinted.", genres=['Short', 'Western'], imdb=Row(id=439, rating='7.4', votes='9847'), languages=['English'], lastupdated='2015-08-13 00:27:59.177000000', metacritic=None, num_mflix_comments=0, plot='A group of bandits stage a brazen train hold-up, only to find a determined posse hot on their heels.', poster='https://m.media-amazon.com/images/M/MV5BMTU3NjE5NzYtYTYyNS00MDVmLWIwYjgtMmYwYWIxZDYyNzU2XkEyXkFqcGdeQXVyNzQzNzQxNzI@._V1_SY1000_SX677_AL_.jpg', rated='TV-G', released=datetime.datetime(1903, 12, 1, 0, 0), runtime=11, title='The Great Train Robbery', tomatoes=Row(boxOffice=None, consensus=None, critic=Row(meter=100, numReviews=6, rating=7.6), dvd=None, fresh=6, lastUpdated=datetime.datetime(2015, 8, 8, 19, 16, 10), production=None, rotten=0, viewer=Row(meter=75, numReviews=2559, rating=3.7), website=None), type='movie', writers=None, year='1903'),
#  Row(_id='573a1390f29313caabcd4803', awards=Row(wins=1, nominations=0, text='1 win.'), cast=['Winsor McCay'], countries=['USA'], directors=['Winsor McCay', 'J. Stuart Blackton'], fullplot='Cartoonist Winsor McCay agrees to create a large set of drawings that will be photographed and made into a motion picture. The job requires plenty of drawing supplies, and the cartoonist must also overcome some mishaps caused by an assistant. Finally, the work is done, and everyone can see the resulting animated picture.', genres=['Animation', 'Short', 'Comedy'], imdb=Row(id=1737, rating='7.3', votes='1034'), languages=['English'], lastupdated='2015-08-29 01:09:03.030000000', metacritic=None, num_mflix_comments=0, plot='Cartoon figures announce, via comic strip balloons, that they will move - and move they do, in a wildly exaggerated style.', poster='https://m.media-amazon.com/images/M/MV5BYzg2NjNhNTctMjUxMi00ZWU4LWI3ZjYtNTI0NTQxNThjZTk2XkEyXkFqcGdeQXVyNzg5OTk2OA@@._V1_SY1000_SX677_AL_.jpg', rated=None, released=datetime.datetime(1911, 4, 8, 0, 0), runtime=7, title='Winsor McCay, the Famous Cartoonist of the N.Y. Herald and His Moving Comics', tomatoes=Row(boxOffice=None, consensus=None, critic=None, dvd=None, fresh=None, lastUpdated=datetime.datetime(2015, 8, 20, 18, 51, 24), production=None, rotten=None, viewer=Row(meter=47, numReviews=89, rating=3.4), website=None), type='movie', writers=['Winsor McCay (comic strip "Little Nemo in Slumberland")', 'Winsor McCay (screenplay)'], year='1911'),
#  Row(_id='573a1390f29313caabcd6377', awards=Row(wins=1, nominations=0, text='1 win.'), cast=['Douglas Fairbanks', 'Eileen Percy', 'Calvert Carter', 'Charles Stevens'], countries=['USA'], directors=['John Emerson'], fullplot='A rich young Easterner who has always wanted to live in "the Wild West" plans to move to a Western town. Unknown to him, the town\'s "wild" days are long gone, and it is an orderly, civilized place now. The townsmen, not wanting to lose a rich potential resident, contrive to make over the town to suit the young man\'s fantasy.', genres=['Comedy', 'Western', 'Romance'], imdb=Row(id=8775, rating='6.9', votes='388'), languages=['English'], lastupdated='2015-06-05 00:40:35.137000000', metacritic=None, num_mflix_comments=0, plot='A rich young Easterner who has always wanted to live in "the Wild West" plans to move to a Western town. Unknown to him, the town\'s "wild" days are long gone, and it is an orderly, ...', poster=None, rated=None, released=datetime.datetime(1917, 6, 24, 0, 0), runtime=72, title='Wild and Woolly', tomatoes=None, type='movie', writers=['Horace B. Carpenter (story)', 'John Emerson', 'Anita Loos'], year='1917'),
#  Row(_id='573a1390f29313caabcd50e5', awards=Row(wins=1, nominations=0, text='1 win.'), cast=['Winsor McCay', 'George McManus', 'Roy L. McCardell'], countries=['USA'], directors=['Winsor McCay'], fullplot='Winsor Z. McCay bets another cartoonist that he can animate a dinosaur. So he draws a big friendly herbivore called Gertie. Then he get into his own picture. Gertie walks through the picture, eats a tree, meets her creator, and takes him carefully on her back for a ride.', genres=['Animation', 'Short', 'Comedy'], imdb=Row(id=4008, rating='7.3', votes='1837'), languages=['English'], lastupdated='2015-08-18 01:03:15.313000000', metacritic=None, num_mflix_comments=0, plot='The cartoonist, Winsor McCay, brings the Dinosaurus back to life in the figure of his latest creation, Gertie the Dinosaur.', poster='https://m.media-amazon.com/images/M/MV5BMTQxNzI4ODQ3NF5BMl5BanBnXkFtZTgwNzY5NzMwMjE@._V1_SY1000_SX677_AL_.jpg', rated=None, released=datetime.datetime(1914, 9, 15, 0, 0), runtime=12, title='Gertie the Dinosaur', tomatoes=Row(boxOffice=None, consensus=None, critic=None, dvd=None, fresh=None, lastUpdated=datetime.datetime(2015, 8, 10, 19, 20, 3), production=None, rotten=None, viewer=Row(meter=None, numReviews=29, rating=3.7), website=None), type='movie', writers=['Winsor McCay'], year='1914'),
#  Row(_id='573a1390f29313caabcd6223', awards=Row(wins=1, nominations=0, text='1 win.'), cast=['Mary Pickford', 'Madlaine Traverse', 'Charles Wellesley', 'Gladys Fairbanks'], countries=['USA'], directors=['Maurice Tourneur'], fullplot="Gwen's family is rich, but her parents ignore her and most of the servants push her around, so she is lonely and unhappy. Her father is concerned only with making money, and her mother cares only about her social position. But one day a servant's irresponsibility creates a crisis that causes everyone to rethink what is important to them.", genres=['Comedy', 'Drama', 'Family'], imdb=Row(id=8443, rating='6.9', votes='884'), languages=['English'], lastupdated='2015-07-27 00:11:31.387000000', metacritic=None, num_mflix_comments=0, plot="Gwen's family is rich, but her parents ignore her and most of the servants push her around, so she is lonely and unhappy. Her father is concerned only with making money, and her mother ...", poster=None, rated=None, released=datetime.datetime(1917, 3, 5, 0, 0), runtime=65, title='The Poor Little Rich Girl', tomatoes=Row(boxOffice=None, consensus=None, critic=None, dvd=None, fresh=None, lastUpdated=datetime.datetime(2015, 8, 21, 18, 0, 25), production='Artcraft', rotten=None, viewer=Row(meter=77, numReviews=137, rating=3.9), website=None), type='movie', writers=['Eleanor Gates (play)', 'Frances Marion (scenario)'], year='1917'),
#  Row(_id='573a1390f29313caabcd5293', awards=Row(wins=1, nominations=0, text='1 win.'), cast=['Pearl White', 'Crane Wilbur', 'Paul Panzer', 'Edward Josè'], countries=['USA'], directors=['Louis J. Gasnier', 'Donald MacKenzie'], fullplot='Young Pauline is left a lot of money when her wealthy uncle dies. However, her uncle\'s secretary has been named as her guardian until she marries, at which time she will officially take possession of her inheritance. Meanwhile, her "guardian" and his confederates constantly come up with schemes to get rid of Pauline so that he can get his hands on the money himself.', genres=['Action'], imdb=Row(id=4465, rating='7.6', votes='744'), languages=['English'], lastupdated='2015-09-12 00:01:18.647000000', metacritic=None, num_mflix_comments=0, plot="Young Pauline is left a lot of money when her wealthy uncle dies. However, her uncle's secretary has been named as her guardian until she marries, at which time she will officially take ...", poster='https://m.media-amazon.com/images/M/MV5BMzgxODk1Mzk2Ml5BMl5BanBnXkFtZTgwMDg0NzkwMjE@._V1_SY1000_SX677_AL_.jpg', rated=None, released=datetime.datetime(1914, 3, 23, 0, 0), runtime=199, title='The Perils of Pauline', tomatoes=Row(boxOffice=None, consensus=None, critic=None, dvd=None, fresh=None, lastUpdated=datetime.datetime(2015, 9, 11, 17, 46, 19), production='Pathè Frères', rotten=None, viewer=Row(meter=None, numReviews=9, rating=2.8), website=None), type='movie', writers=['Charles W. Goddard (screenplay)', 'Basil Dickey (screenplay)', 'Charles W. Goddard (novel)', 'George B. Seitz', 'Bertram Millhauser'], year='1914'),
#  Row(_id='573a1391f29313caabcd7616', awards=Row(wins=1, nominations=0, text='1 win.'), cast=['Mitchell Lewis', 'Alla Nazimova', 'Rose Dione', 'Earl Schenck'], countries=['USA'], directors=['Charles Bryant', 'Alla Nazimova'], fullplot='Salome, the daughter of Herodias, seduces her step-father/uncle Herod, governor of Judea, with a salacious dance. In return, he promises her the head of the prophet John the Baptist.', genres=['Biography', 'Drama', 'History'], imdb=Row(id=13571, rating='6.6', votes='466'), languages=None, lastupdated='2015-04-26 00:03:19.913000000', metacritic=None, num_mflix_comments=0, plot='Salome, the daughter of Herodias, seduces her step-father/uncle Herod, governor of Judea, with a salacious dance. In return, he promises her the head of the prophet John the Baptist.', poster='https://m.media-amazon.com/images/M/MV5BMjA0MTY4MzI2OV5BMl5BanBnXkFtZTgwNTMyODg5MTE@._V1_SY1000_SX677_AL_.jpg', rated=None, released=datetime.datetime(1923, 2, 15, 0, 0), runtime=72, title='Salomè', tomatoes=Row(boxOffice=None, consensus=None, critic=Row(meter=60, numReviews=5, rating=6.5), dvd=None, fresh=3, lastUpdated=datetime.datetime(2015, 6, 13, 19, 0, 41), production=None, rotten=2, viewer=Row(meter=70, numReviews=310, rating=3.9), website=None), type='movie', writers=['Oscar Wilde (play)', 'Natacha Rambova (scenario)'], year='1922'),
#  Row(_id='573a1390f29313caabcd5ea4', awards=Row(wins=1, nominations=0, text='1 win.'), cast=['Tyrone Power Sr.', 'Helen Riaume', 'Marie Walcamp', 'Cora Drew'], countries=['USA'], directors=['Phillips Smalley', 'Lois Weber'], fullplot='While prosecuting a physician for the death of a client after an abortion, the district attorney discovers that his wife helped her society friends and the daughter of her maid obtain and pay for abortions from the physician (and was perhaps herself also a client.)', genres=['Drama'], imdb=Row(id=7558, rating='5.9', votes='247'), languages=['English'], lastupdated='2015-09-07 00:51:32.560000000', metacritic=None, num_mflix_comments=0, plot="A District Attorney's outspoken stand on abortion gets him in trouble with the local community.", poster=None, rated='APPROVED', released=datetime.datetime(1916, 5, 1, 0, 0), runtime=62, title='Where Are My Children?', tomatoes=Row(boxOffice=None, consensus=None, critic=None, dvd=None, fresh=None, lastUpdated=datetime.datetime(2015, 8, 6, 19, 49, 17), production='MCA/Universal Pictures', rotten=None, viewer=Row(meter=50, numReviews=34, rating=3.1), website=None), type='movie', writers=['Lucy Payton (from the story by)', 'Franklin Hall (from the story by)', 'Lois Weber', 'Phillips Smalley'], year='1916'),
#  Row(_id='573a1391f29313caabcd6e2a', awards=Row(wins=1, nominations=0, text='1 win.'), cast=['Buster Keaton', 'Sybil Seely'], countries=['USA'], directors=['Edward F. Cline', 'Buster Keaton'], fullplot="Buster and Sybil exit a chapel as newlyweds. Among the gifts is a portable house you easily put together in one week. It doesn't help that Buster's rival for Sybil switches the numbers on the crates containing the house parts.", genres=['Short', 'Comedy'], imdb=Row(id=11541, rating='8.3', votes='3942'), languages=['English'], lastupdated='2015-05-07 01:07:01.633000000', metacritic=None, num_mflix_comments=0, plot="A newly wedded couple attempt to build a house with a prefabricated kit, unaware that a rival sabotaged the kit's component numbering.", poster=None, rated='TV-G', released=datetime.datetime(1920, 9, 1, 0, 0), runtime=25, title='One Week', tomatoes=Row(boxOffice=None, consensus=None, critic=None, dvd=None, fresh=None, lastUpdated=datetime.datetime(2015, 9, 13, 18, 22, 19), production=None, rotten=None, viewer=Row(meter=91, numReviews=752, rating=4.3), website=None), type='movie', writers=None, year='1920'),
#  Row(_id='573a1390f29313caabcd56df', awards=Row(wins=1, nominations=0, text='1 win.'), cast=['George Beban', 'Clara Williams', 'J. Frank Burke', 'Leo Willis'], countries=['USA'], directors=['Reginald Barker'], fullplot='An immigrant leaves his sweetheart in Italy to find a better life across the sea in the grimy slums of New York. They are eventually reunited and marry. But life in New York is hard and tragedy tarnishes their dream of a better life in the new world.', genres=['Drama'], imdb=Row(id=5557, rating='6.4', votes='175'), languages=['English'], lastupdated='2015-07-27 00:07:43.230000000', metacritic=None, num_mflix_comments=0, plot='An immigrant leaves his sweetheart in Italy to find a better life across the sea in the grimy slums of New York. They are eventually reunited and marry. But life in New York is hard and ...', poster=None, rated='PASSED', released=datetime.datetime(1915, 1, 1, 0, 0), runtime=78, title='The Italian', tomatoes=Row(boxOffice=None, consensus=None, critic=None, dvd=datetime.datetime(2008, 8, 26, 0, 0), fresh=None, lastUpdated=datetime.datetime(2015, 7, 24, 19, 30, 2), production=None, rotten=None, viewer=Row(meter=60, numReviews=204, rating=4.0), website=None), type='movie', writers=['Thomas H. Ince (story)', 'C. Gardner Sullivan (story)'], year='1915'),
#  Row(_id='573a1390f29313caabcd5a93', awards=Row(wins=1, nominations=0, text='1 win.'), cast=['Howard C. Hickman', 'Enid Markey', 'Lola May', 'Kate Bruce'], countries=['USA'], directors=['Reginald Barker', 'Thomas H. Ince', 'Raymond B. West', 'Walter Edwards', 'David Hartford', 'Jay Hunt', 'J. Parker Read Jr.'], fullplot='Allegorical film about peace. A king starts a war, many of the women are against it, people are pressed into service. A count has constructed a submarine and gets the order to sink an ocean liner, that is also carrying - supposedly - ammunition for the enemy. The count refuses to fire the torpedos, and sinks the submarine. He survives, but in a limbo between death and life where he meets Jesus, who takes him over to preach peace. Naturally the king arrests him and sentences him to death for treason, but then Jesus shows him the real face of war.', genres=['Drama'], imdb=Row(id=6517, rating='6.3', votes='162'), languages=None, lastupdated='2015-04-30 02:13:27.863000000', metacritic=None, num_mflix_comments=0, plot='Christ takes on the form of a pacifist count to end a senseless war.', poster='https://m.media-amazon.com/images/M/MV5BMjAwNTIxMjE5N15BMl5BanBnXkFtZTgwODc1Mjg1MzE@._V1_SY1000_SX677_AL_.jpg', rated=None, released=datetime.datetime(1916, 6, 2, 0, 0), runtime=78, title='Civilization', tomatoes=Row(boxOffice=None, consensus=None, critic=None, dvd=None, fresh=None, lastUpdated=datetime.datetime(2015, 8, 7, 18, 42, 35), production=None, rotten=None, viewer=Row(meter=None, numReviews=7, rating=0.0), website=None), type='movie', writers=['C. Gardner Sullivan'], year='1916'),
#  Row(_id='573a1391f29313caabcd71e3', awards=Row(wins=1, nominations=0, text='1 win.'), cast=['Lois Wilson', 'Milton Sills', 'Theodore Roberts', 'Helen Ferguson'], countries=['USA'], directors=['William C. de Mille'], fullplot='Wlliam deMille produced and directed Miss Lulu Bett, a film of extraordinary conviction and insight. It was then often the custom for unmarried women to lodge with family; thus we discover Miss Lulu in a boring Midwestern town, an exploited household drudge for her sister and her overbearing brother-in-law. In the course of the story (based upon the Pulitzer Prize play and novel by Zona Gale), Lulu evolves from slavery into an attractive and self-assured woman, prepared to make her own life. Revealed through wonderful performances and clever use of props, the characters are extraordinarily solid and involving.', genres=['Comedy', 'Drama'], imdb=Row(id=12465, rating='7.2', votes='204'), languages=None, lastupdated='2015-08-21 00:15:46.140000000', metacritic=None, num_mflix_comments=0, plot='Wlliam deMille produced and directed Miss Lulu Bett, a film of extraordinary conviction and insight. It was then often the custom for unmarried women to lodge with family; thus we discover ...', poster='https://m.media-amazon.com/images/M/MV5BMTY5MTY0MzY0Ml5BMl5BanBnXkFtZTgwNjE4NDAxMjE@._V1_SY1000_SX677_AL_.jpg', rated=None, released=datetime.datetime(1921, 11, 1, 0, 0), runtime=71, title='Miss Lulu Bett', tomatoes=Row(boxOffice=None, consensus=None, critic=None, dvd=None, fresh=None, lastUpdated=datetime.datetime(2015, 5, 2, 19, 3, 48), production=None, rotten=None, viewer=Row(meter=None, numReviews=2, rating=2.5), website=None), type='movie', writers=['Clara Beranger (adaptation)', 'Zona Gale (novel)'], year='1921'),
#  Row(_id='573a1391f29313caabcd70b4', awards=Row(wins=1, nominations=0, text='1 win.'), cast=['Pomeroy Cannon', 'Josef Swickard', 'Bridgetta Clark', 'Rudolph Valentino'], countries=['USA'], directors=['Rex Ingram'], fullplot='Julio Madariaga is the Argentine patriarch of a wealthy family. He has two daughters, the elder wed to a Frenchman and the other to a German. He prefers the Frenchman and his family, especially his grandson Julio, causing jealousy from the German and his three sons. When Madariaga dies, the family splits up, each son-in-law returning to his own country. The Frenchman and his own move to Paris, where Julio becomes an artist and has an affair with an unhappily married woman, the lovely Marguerite Laurier. Her husband finds out, but before he can finalize a divorce, World War One rears its head and both sides of the family will endure great suffering in the conflict, especially since they must fight one another on the battlefield.', genres=['Drama', 'Romance', 'War'], imdb=Row(id=12190, rating='7.9', votes='2475'), languages=None, lastupdated='2015-08-24 00:59:30.430000000', metacritic=None, num_mflix_comments=1, plot='An extended family split up in France and Germany find themselves on opposing sides of the battlefield during World War I.', poster='https://m.media-amazon.com/images/M/MV5BOTU1ODQyYTctODhkNy00YWRmLWE2YzYtMTQ5ZjA3OTNiN2QyXkEyXkFqcGdeQXVyMzE0MjY5ODA@._V1_SY1000_SX677_AL_.jpg', rated='PASSED', released=datetime.datetime(1923, 3, 31, 0, 0), runtime=150, title='The Four Horsemen of the Apocalypse', tomatoes=Row(boxOffice=None, consensus=None, critic=None, dvd=None, fresh=None, lastUpdated=datetime.datetime(2015, 7, 28, 18, 34, 16), production='Metro Pictures Corporation', rotten=None, viewer=Row(meter=76, numReviews=507, rating=3.9), website=None), type='movie', writers=['Vicente Blasco Ibèèez (novel)', 'June Mathis (written for the screen by)'], year='1921'),
#  Row(_id='573a1390f29313caabcd4eaf', awards=Row(wins=1, nominations=0, text='1 win.'), cast=['Jane Gail', 'Ethel Grandin', 'William H. Turner', 'Matt Moore'], countries=['USA'], directors=['George Loane Tucker'], fullplot=None, genres=['Crime', 'Drama'], imdb=Row(id=3471, rating='6.0', votes='371'), languages=['English'], lastupdated='2015-09-15 02:07:14.247000000', metacritic=None, num_mflix_comments=1, plot='A woman, with the aid of her police officer sweetheart, endeavors to uncover the prostitution ring that has kidnapped her sister, and the philanthropist who secretly runs it.', poster='https://m.media-amazon.com/images/M/MV5BYzk0YWQzMGYtYTM5MC00NjM2LWE5YzYtMjgyNDVhZDg1N2YzXkEyXkFqcGdeQXVyMzE0MjY5ODA@._V1_SY1000_SX677_AL_.jpg', rated='TV-PG', released=datetime.datetime(1913, 11, 24, 0, 0), runtime=88, title='Traffic in Souls', tomatoes=Row(boxOffice=None, consensus=None, critic=None, dvd=datetime.datetime(2008, 8, 26, 0, 0), fresh=None, lastUpdated=datetime.datetime(2015, 8, 10, 18, 33, 55), production=None, rotten=None, viewer=Row(meter=57, numReviews=85, rating=3.0), website=None), type='movie', writers=None, year='1913'),
#  Row(_id='573a1391f29313caabcd6ea2', awards=Row(wins=0, nominations=1, text='1 nomination.'), cast=['Edward Jobson', 'Beulah Booker', 'Edward Connelly', 'Edward Alexander'], countries=['USA'], directors=['Herbert Blachè', 'Winchell Smith'], fullplot="Nick Van Alstyne owns the Henrietta silver mine and is very rich. His son Bertie is naive and spoiled. His daughter Rose is married to shady investor Mark. Mark wrecks Bertie's wedding plans by making him take the blame for Mark's illegitimate daughter. Mark also nearly ruins the family business by selling off Henrietta stock at too low a price. Bertie, of all people, must come to the rescue on the trading floor.", genres=['Comedy'], imdb=Row(id=11652, rating='6.2', votes='1020'), languages=None, lastupdated='2015-06-20 00:38:08.303000000', metacritic=None, num_mflix_comments=0, plot='The simple-minded son of a rich financier must find his own way in the world.', poster='https://m.media-amazon.com/images/M/MV5BZDNiODA3NzQtNTBmZS00NTM3LWJlOGMtMDg2NzFiNDU2M2M3XkEyXkFqcGdeQXVyMjUxODE0MDY@._V1_SY1000_SX677_AL_.jpg', rated=None, released=datetime.datetime(1920, 9, 1, 0, 0), runtime=77, title='The Saphead', tomatoes=Row(boxOffice=None, consensus=None, critic=None, dvd=datetime.datetime(2000, 1, 11, 0, 0), fresh=None, lastUpdated=datetime.datetime(2015, 6, 23, 19, 23, 34), production=None, rotten=None, viewer=Row(meter=49, numReviews=435, rating=3.3), website=None), type='movie', writers=['Bronson Howard (original play "The Henrietta")', 'Victor Mapes (play)', 'June Mathis (scenario)', 'Winchell Smith (play)'], year='1920'),
#  Row(_id='573a1391f29313caabcd72f0', awards=Row(wins=2, nominations=0, text='2 wins.'), cast=['Richard Barthelmess', 'Gladys Hulette', 'Walter P. Lewis', 'Ernest Torrence'], countries=['USA'], directors=['Henry King'], fullplot='When three thuggish men are responsible for the death of his father and the crippling of his brother, young David must choose between supporting his family or risking his life and exacting vengeance.', genres=['Drama'], imdb=Row(id=12763, rating='8.1', votes='1455'), languages=None, lastupdated='2015-08-23 01:12:08.943000000', metacritic=None, num_mflix_comments=0, plot='When three thuggish men are responsible for the death of his father and the crippling of his brother, young David must choose between supporting his family or risking his life and exacting vengeance.', poster='https://m.media-amazon.com/images/M/MV5BMjIwMzA3MDAyNl5BMl5BanBnXkFtZTgwNzMyNTE1MjE@._V1_SY1000_SX677_AL_.jpg', rated=None, released=datetime.datetime(1921, 12, 31, 0, 0), runtime=99, title="Tol'able David", tomatoes=Row(boxOffice=None, consensus=None, critic=None, dvd=datetime.datetime(1999, 3, 23, 0, 0), fresh=None, lastUpdated=datetime.datetime(2015, 8, 26, 18, 24, 46), production='Universum Film A.G. (UFA)', rotten=None, viewer=Row(meter=70, numReviews=249, rating=3.3), website=None), type='movie', writers=['Joseph Hergesheimer (novel)', 'Edmund Goulding', 'Henry King'], year='1921'),
#  Row(_id='573a1391f29313caabcd7e6e', awards=Row(wins=1, nominations=0, text='1 win.'), cast=['Rin Tin Tin', 'Nanette', 'Charles Farrell', 'June Marlowe'], countries=['USA'], directors=['Noel M. Smith'], fullplot='A fire in the mountains drive a wolf pack into the nearby desert where they terrorize the local residents. The leader of the wolf pack is Lobo, actually a halfbreed (Rin Tin Tin). When the pack is discovered hunting a herd of cows, a posse gives chase. Lobo leaves his pack to lead the posse away. He is injured and found by a local prospector, Dave Weston (Charles Farrell). The prospector nurses Lobo back to health and the two become close friends. Meanwhile, Weston has made a Borax find in the area. His girl friend May Barstowe (June Marlowe), daughter of a wealthy rancher, is pleased. However the local chemist, Borax Horton (Pat Hartigan), actually a claim jumper, plans to steal the claim. In a sandstorm he is able to shoot Weston and leave the prospector for dead in the desert. Lobo tries to get a message to May, but runs afoul of Horton. Finally, he is able to bring May to Weston, who are then both terrorized by Horton. Lobo calls upon his pack to eliminate the menace, allowing for the young lovers to finally find happiness. Lobo also finds happiness being reunited with his mate, Nannette.', genres=['Adventure', 'Romance', 'Western'], imdb=Row(id=15687, rating='6.7', votes='188'), languages=['English'], lastupdated='2015-04-17 00:50:41.207000000', metacritic=None, num_mflix_comments=0, plot='A fire in the mountains drive a wolf pack into the nearby desert where they terrorize the local residents. The leader of the wolf pack is Lobo, actually a halfbreed (Rin Tin Tin). When the ...', poster=None, rated='PASSED', released=datetime.datetime(1925, 11, 28, 0, 0), runtime=74, title='Clash of the Wolves', tomatoes=Row(boxOffice=None, consensus=None, critic=None, dvd=None, fresh=None, lastUpdated=datetime.datetime(2015, 8, 24, 18, 53, 23), production=None, rotten=None, viewer=Row(meter=60, numReviews=416, rating=3.6), website=None), type='movie', writers=['Charles Logue (by)'], year='1925'),
#  Row(_id='573a1391f29313caabcd820b', awards=Row(wins=1, nominations=0, text='1 win.'), cast=['Ronald Colman', 'Neil Hamilton', 'Ralph Forbes', 'Alice Joyce'], countries=['USA'], directors=['Herbert Brenon'], fullplot='Michael "Beau" Geste leaves England in disgrace and joins the infamous French Foreign Legion. He is reunited with his two brothers in North Africa, where they face greater danger from their own sadistic commander than from the rebellious Arabs.', genres=['Action', 'Adventure', 'Drama'], imdb=Row(id=16634, rating='6.9', votes='222'), languages=['English'], lastupdated='2015-08-25 00:40:54.383000000', metacritic=None, num_mflix_comments=0, plot='Michael "Beau" Geste leaves England in disgrace and joins the infamous French Foreign Legion. He is reunited with his two brothers in North Africa, where they face greater danger from their...', poster=None, rated=None, released=datetime.datetime(1926, 8, 25, 0, 0), runtime=101, title='Beau Geste', tomatoes=Row(boxOffice=None, consensus=None, critic=None, dvd=datetime.datetime(2000, 3, 28, 0, 0), fresh=None, lastUpdated=datetime.datetime(2015, 4, 18, 18, 16, 4), production=None, rotten=None, viewer=Row(meter=38, numReviews=75, rating=3.6), website=None), type='movie', writers=['Herbert Brenon (adaptation)', 'John Russell (adaptation)', 'Paul Schofield', 'Percival Christopher Wren (novel)'], year='1926'),
#  Row(_id='573a1391f29313caabcd89aa', awards=Row(wins=5, nominations=1, text='Won 2 Oscars. Another 3 wins & 1 nomination.'), cast=['Clara Bow', "Charles 'Buddy' Rogers", 'Richard Arlen', 'Jobyna Ralston'], countries=['USA'], directors=['William A. Wellman', "Harry d'Abbadie d'Arrast"], fullplot='Two young men fall in love with the same same girl. After the US enters WWI, both join the Air Corps and become aces. They remain friends, but the relation to the girl threatens their friendship.', genres=['Drama', 'Romance', 'War'], imdb=Row(id=18578, rating='7.8', votes='7196'), languages=['English'], lastupdated='2015-09-02 00:36:34.413000000', metacritic=None, num_mflix_comments=1, plot='Two young men, one rich, one middle class, who are in love with the same woman, become fighter pilots in World War I.', poster='https://m.media-amazon.com/images/M/MV5BYTI1YjgzZmMtZmIyYy00YTkwLTgyOWEtOTVlNTFkZmMzNTk3XkEyXkFqcGdeQXVyMDI2NDg0NQ@@._V1_SY1000_SX677_AL_.jpg', rated='PG-13', released=datetime.datetime(1929, 1, 5, 0, 0), runtime=144, title='Wings', tomatoes=Row(boxOffice=None, consensus="Subsequent war epics may have borrowed heavily from the original Best Picture winner, but they've all lacked Clara Bow's luminous screen presence and William Wellman's deft direction.", critic=Row(meter=95, numReviews=37, rating=7.4), dvd=datetime.datetime(2012, 1, 24, 0, 0), fresh=35, lastUpdated=datetime.datetime(2015, 9, 3, 19, 19, 24), production='Unknown', rotten=2, viewer=Row(meter=77, numReviews=3316, rating=3.8), website=None), type='movie', writers=['John Monk Saunders (story)', 'Hope Loring (screenplay)', 'Louis D. Lighton (screenplay)', 'Julian Johnson (titles)'], year='1927'),
#  Row(_id='573a1391f29313caabcd883d', awards=Row(wins=3, nominations=0, text='3 wins.'), cast=['Albert Dieudonnè', 'Vladimir Roudenko', 'Edmond Van Daèle', 'Alexandre Koubitzky'], countries=['France'], directors=['Abel Gance'], fullplot="A massive six-hour biopic of Napoleon, tracing his career from his schooldays (where a snowball fight is staged like a military campaign), his flight from Corsica, through the French Revolution (where a real storm is intercut with a political storm) and the Terror, culminating in his triumphant invasion of Italy in 1797 (the film stops there because it was intended to be part one of six, but director Abel Gance never raised the money to make the other five). The film's legendary reputation is due to the astonishing range of techniques that Gance uses to tell his story, culminating in the final twenty-minute triptych sequence, which alternates widescreen panoramas with complex multiple- image montages projected simultaneously on three screens.", genres=['Biography', 'Drama', 'History'], imdb=Row(id=18192, rating='7.4', votes='5064'), languages=None, lastupdated='2015-08-21 00:07:08.593000000', metacritic=None, num_mflix_comments=0, plot="A film about the French Field Marshal's youth and early military career.", poster='https://m.media-amazon.com/images/M/MV5BOGY4M2ZlMGQtMzM4ZC00YjdhLTkxOGQtNTU4NjZhY2IwNmRkXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_SY1000_SX677_AL_.jpg', rated=None, released=datetime.datetime(1929, 2, 17, 0, 0), runtime=240, title='Napoleon', tomatoes=Row(boxOffice=None, consensus=None, critic=Row(meter=90, numReviews=20, rating=8.7), dvd=None, fresh=18, lastUpdated=datetime.datetime(2015, 8, 16, 18, 17, 41), production='Universal Studios Home Entertainment', rotten=2, viewer=Row(meter=91, numReviews=1543, rating=4.3), website=None), type='movie', writers=['Abel Gance'], year='1927'),
#  Row(_id='573a1391f29313caabcd8ba2', awards=Row(wins=0, nominations=2, text='2 nominations.'), cast=['Lon Chaney', 'Bernard Siegel', 'Loretta Young', 'Cissy Fitzgerald'], countries=['USA'], directors=['Herbert Brenon'], fullplot='As professional clowns Tito and Simon are traveling, they happen upon an abandoned child, whom they take in and name Simonetta. When Simonetta is older, she becomes a circus performer herself. One day she is looking for roses, and climbs into the garden of Count Luigi Ravelli. The count becomes infatuated with her, but she leaves as soon as possible. Sometime later, Ravelli consults a doctor about his fits of uncontrollable laughter, and there he meets Tito, who has come to seek help for his fits of uncontrollable weeping. The two decide to help each other, and they establish a friendship, but problems arise when they realize that they are both in love with Simonetta.', genres=['Drama'], imdb=Row(id=19074, rating='7.8', votes='1257'), languages=None, lastupdated='2015-09-11 00:00:30.930000000', metacritic=None, num_mflix_comments=0, plot='A professional clown and a self-indulgent count learn to help each other with their problems, but then become romantic rivals.', poster='https://m.media-amazon.com/images/M/MV5BMTk1MjEzOTc4Ml5BMl5BanBnXkFtZTgwODU1NDM4MTE@._V1_SY1000_SX677_AL_.jpg', rated='PASSED', released=datetime.datetime(1928, 4, 14, 0, 0), runtime=73, title='Laugh, Clown, Laugh', tomatoes=Row(boxOffice=None, consensus=None, critic=None, dvd=None, fresh=None, lastUpdated=datetime.datetime(2015, 9, 10, 19, 15, 57), production='MGM', rotten=None, viewer=Row(meter=93, numReviews=508, rating=4.1), website=None), type='movie', writers=['David Belasco (play)', 'Tom Cushing (play)', 'Joseph Farnham (titles)', 'Elizabeth Meehan'], year='1928'),
#  Row(_id='573a1391f29313caabcd7626', awards=Row(wins=1, nominations=0, text='1 win.'), cast=['Wallace Beery', 'Sam De Grasse', 'Enid Bennett', 'Paul Dickey'], countries=['USA'], directors=['Allan Dwan'], fullplot="Amid big-budget medieval pageantry, King Richard goes on the Crusades leaving his brother Prince John as regent, who promptly emerges as a cruel, grasping, treacherous tyrant. Apprised of England's peril by message from his lady-love Marian, the dashing Earl of Huntingdon endangers his life and honor by returning to oppose John, but finds himself and his friends outlawed, and Marian apparently dead. Enter Robin Hood, acrobatic champion of the oppressed, laboring to set things right through swash buckling feats and cliffhanging perils!", genres=['Adventure', 'Romance', 'Family'], imdb=Row(id=13556, rating='7.7', votes='1460'), languages=['English'], lastupdated='2015-08-11 00:29:16.047000000', metacritic=None, num_mflix_comments=0, plot='A nobleman becomes the vigilante Robin Hood who protects the oppressed English people from the tyrannical Prince John.', poster='https://m.media-amazon.com/images/M/MV5BYzRmMWIyNDEtYTRmYS00Y2FlLWJhOGUtYWZmNTI1YzZjOTc2L2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMjUxODE0MDY@._V1_SY1000_SX677_AL_.jpg', rated=None, released=datetime.datetime(1922, 10, 18, 0, 0), runtime=143, title='Robin Hood', tomatoes=Row(boxOffice=None, consensus=None, critic=Row(meter=100, numReviews=8, rating=8.4), dvd=datetime.datetime(2004, 2, 3, 0, 0), fresh=8, lastUpdated=datetime.datetime(2015, 7, 14, 18, 21, 21), production=None, rotten=0, viewer=Row(meter=70, numReviews=659, rating=3.6), website=None), type='movie', writers=['Douglas Fairbanks (story)'], year='1922'),
# ...
#  Row(_id='573a1394f29313caabce025e', awards=Row(wins=1, nominations=1, text='1 win & 1 nomination.'), cast=['Pablo Picasso'], countries=['France'], directors=['Henri-Georges Clouzot'], fullplot="Using a specially designed transparent 'canvas' to provide an unobstructed view, Picasso creates as the camera rolls. He begins with simple works that take shape after only a single brush stroke. He then progresses to more complex paintings, in which he repeatedly adds and removes elements, transforming the entire scene at will, until at last the work is complete.", genres=['Documentary'], imdb=Row(id=49531, rating='7.9', votes='1260'), languages=['French'], lastupdated='2015-06-25 00:06:24.160000000', metacritic=None, num_mflix_comments=0, plot='A filmed record of Pablo Picasso painting numerous canvases for the camera, allowing us to see his creative process at work.', poster='https://m.media-amazon.com/images/M/MV5BMzVjMGMzODctYjE0Mi00OTBiLWE3MTItOGE1YjI0YzVhNjM0XkEyXkFqcGdeQXVyNjg3MTIwODI@._V1_SY1000_SX677_AL_.jpg', rated='PG', released=datetime.datetime(1956, 5, 18, 0, 0), runtime=78, title='Le mystère Picasso', tomatoes=Row(boxOffice=None, consensus=None, critic=Row(meter=83, numReviews=18, rating=7.0), dvd=datetime.datetime(2003, 1, 14, 0, 0), fresh=15, lastUpdated=datetime.datetime(2015, 7, 14, 18, 28, 28), production=None, rotten=3, viewer=Row(meter=82, numReviews=867, rating=3.9), website=None), type='movie', writers=None, year='1956'),
#  Row(_id='573a1394f29313caabce015a', awards=Row(wins=0, nominations=3, text='Nominated for 2 Oscars. Another 1 nomination.'), cast=['Bing Crosby', 'Grace Kelly', 'Frank Sinatra', 'Celeste Holm'], countries=['USA'], directors=['Charles Walters'], fullplot='C.K. Dexter-Haven, a successful popular jazz musician, lives in a mansion near his ex-wife\'s Tracy Lord\'s family estate. She is on the verge of marrying a man blander and safer than Dex, who tries to win Tracy\'s heart again. Mike Connor, an undercover tabloid reporter, also falls for Tracy while covering the nuptials for Spy magazine. Tracy must choose between the three men as she discovers that "safe" can mean "deadly dull" when it comes to husbands and life.', genres=['Comedy', 'Musical', 'Romance'], imdb=Row(id=49314, rating='7.0', votes='9500'), languages=['English'], lastupdated='2015-08-21 00:11:25.423000000', metacritic=None, num_mflix_comments=0, plot="C.K. Dexter-Haven, a successful popular jazz musician, lives in a mansion near his ex-wife's Tracy Lord's family estate. She is on the verge of marrying a man blander and safer than Dex, ...", poster='https://m.media-amazon.com/images/M/MV5BZjk2OGU5MmUtZDg5Yi00NmFhLWI5MjEtNTZlZTA2N2JmMDVkXkEyXkFqcGdeQXVyMDI2NDg0NQ@@._V1_SY1000_SX677_AL_.jpg', rated='APPROVED', released=datetime.datetime(1956, 7, 17, 0, 0), runtime=111, title='High Society', tomatoes=Row(boxOffice=None, consensus=None, critic=Row(meter=80, numReviews=15, rating=6.8), dvd=datetime.datetime(2003, 4, 22, 0, 0), fresh=12, lastUpdated=datetime.datetime(2015, 9, 3, 18, 32, 32), production='MGM Home Entertainment', rotten=3, viewer=Row(meter=83, numReviews=11325, rating=3.8), website=None), type='movie', writers=['John Patrick (screenplay)', 'Philip Barry (play)'], year='1956'),
#  Row(_id='573a1394f29313caabce01c3', awards=Row(wins=13, nominations=8, text='Won 5 Oscars. Another 8 wins & 8 nominations.'), cast=['Deborah Kerr', 'Yul Brynner', 'Rita Moreno', 'Martin Benson'], countries=['USA'], directors=['Walter Lang'], fullplot='Mrs. Anna Leonowens and her son Louis arrive in Bangkok, where she has been contracted to teach English to the children of the royal household. She threatens to leave when the house she had been promised is not available, but falls in love with the children. A new slave, a gift of a vassal king, translates "Uncle Tom\'s Cabin" into a Siamese ballet. After expressing her unhappiness at being with the King, the slave decides to make an attempt to escape with her lover. Anna and the King start to fall in love, but her headstrong upbringing inhibits her from joining his harem. She is just about to leave Siam but something important she finds out makes her think about changing her mind.', genres=['Biography', 'Drama', 'Musical'], imdb=Row(id=49408, rating='7.5', votes='18067'), languages=['English', 'Thai'], lastupdated='2015-09-14 23:58:15.860000000', metacritic=None, num_mflix_comments=1, plot="A widow accepts a job as a live-in governess to the King of Siam's children.", poster='https://m.media-amazon.com/images/M/MV5BNmJkYTViMzItZDM3YS00MDU2LTkzYWItMGJkYjVjMjU2YjNlL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SY1000_SX677_AL_.jpg', rated='G', released=datetime.datetime(1956, 6, 29, 0, 0), runtime=133, title='The King and I', tomatoes=Row(boxOffice=None, consensus=None, critic=Row(meter=96, numReviews=25, rating=8.2), dvd=datetime.datetime(1999, 4, 27, 0, 0), fresh=24, lastUpdated=datetime.datetime(2015, 9, 2, 18, 58, 28), production='20th Century Fox', rotten=1, viewer=Row(meter=83, numReviews=60751, rating=3.6), website=None), type='movie', writers=['Ernest Lehman (screenplay)', 'Oscar Hammerstein II (book)', 'Margaret Landon (from their musical play based on Anna and the King of Siam by)'], year='1956'),
#  Row(_id='573a1394f29313caabce0230', awards=Row(wins=5, nominations=1, text='Won 1 Oscar. Another 4 wins & 1 nomination.'), cast=['Frèdèric Dumas', 'Albert Falco', 'Jacques-Yves Cousteau', 'Franèois Saout'], countries=['France', 'Italy'], directors=['Jacques-Yves Cousteau', 'Louis Malle'], fullplot=None, genres=['Documentary'], imdb=Row(id=49518, rating='7.3', votes='833'), languages=['French'], lastupdated='2015-09-05 00:35:56.487000000', metacritic=None, num_mflix_comments=1, plot=None, poster=None, rated=None, released=datetime.datetime(1956, 8, 15, 0, 0), runtime=86, title='The Silent World', tomatoes=Row(boxOffice=None, consensus=None, critic=None, dvd=None, fresh=None, lastUpdated=datetime.datetime(2015, 9, 10, 19, 14, 29), production=None, rotten=None, viewer=Row(meter=84, numReviews=516, rating=3.9), website=None), type='movie', writers=['Jacques-Yves Cousteau'], year='1956'),
#  Row(_id='573a1394f29313caabce0305', awards=Row(wins=1, nominations=0, text='1 win.'), cast=['Winston Hibler'], countries=['USA'], directors=['James Algar'], fullplot="A feature-length drama showing the changing World of Nature, the sky, the sea, the sun, planets,insects and volcanic action. A story of Nature's strange and intricate designs for survival and her many methods of perpetrating life.", genres=['Documentary', 'Family'], imdb=Row(id=49733, rating='8.0', votes='66'), languages=['English'], lastupdated='2015-04-10 00:35:54.743000000', metacritic=None, num_mflix_comments=1, plot="A feature-length drama showing the changing World of Nature, the sky, the sea, the sun, planets,insects and volcanic action. A story of Nature's strange and intricate designs for survival and her many methods of perpetrating life.", poster='https://m.media-amazon.com/images/M/MV5BM2I0Y2ZjNDEtOTI0Zi00ZTAzLThjNTQtOGU3N2Q3MTFmOTRiXkEyXkFqcGdeQXVyMTQ3Njg3MQ@@._V1_SY1000_SX677_AL_.jpg', rated='PASSED', released=datetime.datetime(1956, 11, 6, 0, 0), runtime=70, title='Secrets of Life', tomatoes=Row(boxOffice=None, consensus=None, critic=None, dvd=None, fresh=None, lastUpdated=datetime.datetime(2015, 8, 5, 19, 29, 24), production=None, rotten=None, viewer=Row(meter=33, numReviews=98, rating=2.6), website=None), type='movie', writers=['James Algar'], year='1956'),
#  Row(_id='573a1394f29313caabce0317', awards=Row(wins=0, nominations=3, text='3 nominations.'), cast=['Romy Schneider', 'Karlheinz Bèhm', 'Magda Schneider', 'Gustav Knuth'], countries=['Austria'], directors=['Ernst Marischka'], fullplot="Through her Hungarian teacher the young Empress Sissi is enchanted by Hungary, a country she has never visited, but feels an affinity with. The Council of Ministers wants to punish some Hungarian rebels, but Emperor Franz Joseph gives all the rebels amnesty, including their leader, Count Andrassy. The Emperor is influenced by his wife, who says that you cannot win a country with force, only with love. The Hungarians are deeply affected by Sissi's love for their country, and want to crown Franz Joseph and Sissi to King and Queen of Hungary. At a big ball for the Hungarians the Emperor's mother, Archduchess Sophie, insults Count Andrassy, by refusing to greet him. Sissi rescues the situation by asking Count Andrassy to dance with her. Sissi gives birth to a daughter, but her happiness is broken, when Archduchess Sophie decides to nourish the baby herself, and takes it away from its mother. Sissi runs away to her family in Bavaria. Franz Joseph follows her, and takes her on a honeymoon in the Austrian Alps. Sissi's mother, Duchess Ludovika, goes to Vienna to implore her sister, Archduchess Sophie, to give the baby back to Sissi.", genres=['Drama', 'History'], imdb=Row(id=49762, rating='6.5', votes='4131'), languages=['German', 'Hungarian'], lastupdated='2015-09-12 00:22:05.233000000', metacritic=None, num_mflix_comments=0, plot='The second in a trilogy of movies about Elisabeth "Sissi" of Austria, the film chronicles the married life of the young empress as she tries to adjust to formal and strict life in the palace and an overbearing mother-in-law.', poster='https://m.media-amazon.com/images/M/MV5BZTc3ZTI4ZDYtZTNkYS00NTU3LTgwY2QtNDZkYWZmNDJmOTIyXkEyXkFqcGdeQXVyNDE5MTU2MDE@._V1_SY1000_SX677_AL_.jpg', rated=None, released=datetime.datetime(1956, 12, 1, 0, 0), runtime=107, title='Sissi: The Young Empress', tomatoes=Row(boxOffice=None, consensus=None, critic=None, dvd=datetime.datetime(2007, 9, 11, 0, 0), fresh=None, lastUpdated=datetime.datetime(2015, 9, 10, 18, 57, 2), production=None, rotten=None, viewer=Row(meter=88, numReviews=3683, rating=4.1), website=None), type='movie', writers=['Ernst Marischka'], year='1956'),
#  Row(_id='573a1394f29313caabce0326', awards=Row(wins=0, nominations=5, text='Won 1 Oscar. Another 4 nominations.'), cast=['Judy Holliday', 'Paul Douglas', 'Fred Clark', 'John Williams'], countries=['USA'], directors=['Richard Quine'], fullplot="Laura Partridge is a very enthusiastic small stockholder of 10 shares in International Projects, a large corporation based in New York. She attends her first stockholder meeting ready to question the board of directors from their salaries to their operations. These are not the questions which the board expected to be asked of them, especially since they are all crooked, except for Edward McKeever, the current CEO who has resigned in order to take an advisory position at the Pentagon. Following the meeting, he bumps into Laura and offers to drive her home. On the way there, Laura displays her enthusiasm for being a stockholder, as a result, Edward takes a liking to her. With Edward in Washington, John Blessington and Clifford Snell establish their hold on International Projects - They see greater riches now that Edward has influence with the US senate, especially with the awarding of federal contracts, unfortunately for them he is honest, and won't do their bidding. In the meantime, Laura continues to be a nusance to the board. Blessington believes the only way to silence her, is to give her a high paying position with the company. The idea is for her to do absolutely nothing - Laura has other plans. She begins to correspond with other small stockholders in the company - a problem for the board. They decide to use her influence on Edward and send her to Washington to get contracts. Laura now knowing their true intentions for her, has her own agenda, that is, get Edward back in charge of the company.", genres=['Comedy', 'Romance'], imdb=Row(id=49777, rating='7.6', votes='1072'), languages=['English'], lastupdated='2015-08-26 00:16:41.837000000', metacritic=None, num_mflix_comments=0, plot='A minority stockholder takes on the crooked board of directors at a billion dollar corporation.', poster='https://m.media-amazon.com/images/M/MV5BNGUwYmZlNmMtZjhmZi00ODgwLThkNTItNTczYmU2MDQ0NmZkXkEyXkFqcGdeQXVyNjE5MjUyOTM@._V1_SY1000_SX677_AL_.jpg', rated='APPROVED', released=datetime.datetime(1956, 8, 22, 0, 0), runtime=99, title='The Solid Gold Cadillac', tomatoes=Row(boxOffice=None, consensus=None, critic=Row(meter=100, numReviews=5, rating=7.5), dvd=datetime.datetime(2003, 10, 28, 0, 0), fresh=5, lastUpdated=datetime.datetime(2015, 8, 24, 19, 26, 42), production='Sony Pictures Entertainment', rotten=0, viewer=Row(meter=65, numReviews=525, rating=3.6), website=None), type='movie', writers=['Abe Burrows (screen play)', 'George S. Kaufman (from the play by)', 'Howard Teichmann (from the play by)'], year='1956'),
#  Row(_id='573a1394f29313caabce033b', awards=Row(wins=0, nominations=1, text='1 nomination.'), cast=['Dirk Bogarde', 'Jon Whiteley', 'Michael Hordern', 'Cyril Cusack'], countries=['UK'], directors=['Philip Leacock'], fullplot="British diplomat Harrington Brande takes up his new post in Spain accompanied by his son Nicholas. The posting is something of a disappointment to the elder Brande who was hoping for a promotion. That his wife had left him seems to have affected his career. Nicholas sees it all as something of an adventure and soon becomes fast friends with the new gardener, Jose. As Nicholas begins to spend more time with Jose, his father takes offense and is concerned at the boy's loss of affection for him, or so he perceives. It leads him to bar Nicholas from even speaking to the gardener. As tensions mount, another servant frames Jose for theft forcing everyone to review the situation.", genres=['Drama'], imdb=Row(id=49787, rating='6.8', votes='545'), languages=['English'], lastupdated='2015-08-22 00:04:06.813000000', metacritic=None, num_mflix_comments=1, plot='British diplomat Harrington Brande takes up his new post in Spain accompanied by his son Nicholas. The posting is something of a disappointment to the elder Brande who was hoping for a ...', poster='https://m.media-amazon.com/images/M/MV5BZTFiZWI5NjgtNDgyMy00MGQ0LWIwNjMtMTA3MWNmZjZiMWI0XkEyXkFqcGdeQXVyMDUyOTUyNQ@@._V1_SY1000_SX677_AL_.jpg', rated=None, released=datetime.datetime(1957, 1, 28, 0, 0), runtime=91, title='The Spanish Gardener', tomatoes=Row(boxOffice=None, consensus=None, critic=None, dvd=None, fresh=None, lastUpdated=datetime.datetime(2015, 9, 13, 18, 20, 55), production='VCI Entertainment', rotten=None, viewer=Row(meter=None, numReviews=64, rating=3.3), website='http://www.vcientertainment.com/Film-Categories/The-Spanish-Gardener'), type='movie', writers=['John Bryan (screenplay)', 'A.J. Cronin (novel)', 'Lesley Storm (screenplay)'], year='1956'),
#  ...]

# %% [markdown]
# ## Transformaciones en RDD
#
# En esta sección veremos brevemente algunas operaciones de transformación sobre el RDD que contiene los datos de una colección de MongoDB.
#
# En la sección anterior convertimos el DataFrame a RDD y es sobre este último que haremos todo el trabajo.

# %%
print("\n" + "="*60)
print("TRANSFORMACIONES RDD")
print("="*60)


# Transformación 1: MAP - Extraer solo el runtime y el título
rdd_productos = rdd.map(lambda row: (row['runtime'], row['title']))
print("\n1. MAP - Runtime y Title:")
print(rdd_productos.take(3))

# Transformación 2: FILTER - Películas del año mayor al 2000
# Si observas el schema verás que year tiene el tipo de datos string
# por lo tanto haremos un cast por medio de una función

def gt_2000(row):
    try:
        #convertirmos a entero la columna year
        return int(row['year']) > 2000
    except:
        return False  # year nulo, vacío o no convertible

rdd_2000 = rdd.filter(gt_2000)
print("\n2. FILTER - Películas año mayor al 2000:")
print(f"Total películas con año > 2000: {rdd_2000.count()}")

# Transformación 3: FLATMAP - Dividir genres si están en un array
rdd_categorias = rdd.flatMap(lambda row: row['genres'] if isinstance(row['genres'], list) else [row['genres']])
print("\n3. FLATMAP - Todas los Géneros:")
print(rdd_categorias.take(5))
# Out:
# ============================================================
# TRANSFORMACIONES RDD
# ============================================================
#
# 1. MAP - Runtime y Title:
# [(72, 'Regeneration'), (26, 'High and Dizzy'), (117, 'Foolish Wives')]
#
# 2. FILTER - Películas año mayor al 2000:
# Total películas con año > 2000: 11988
#
# 3. FLATMAP - Todas los Géneros:
# ['Biography', 'Crime', 'Drama', 'Comedy', 'Short']

# %% [markdown]
# ## Acciones en RDD
#
# Ahora veremos algunas acciones. Recuerda que todo esto se está realizando sobre un RDD que contiene una colección de una base de datos en MongoDB Atlas

# %%
print("\n" + "="*60)
print("ACCIONES RDD")
print("="*60)

# Acción 1: COUNT - Contar elementos
total_peliculas = rdd.count()
print(f"\n1. COUNT - Total de Películas: {total_peliculas}")

# Acción 2: FIRST - Primer elemento Awards.Wins
# En este caso vamos a acceder a un objeto/campo anidado de MongoDB.
# En RDD este se convierte en un struct llamado awards que dentro
# tiene wins.
primera_pelicula = rdd.first()
print(f"\n2. FIRST - Primera Película Premios Ganados: {primera_pelicula['awards']['wins']}")

#Podemos imprimir otro objeto anidado. Observa en MongoDB Atlas que el campo
# imdb tiene los campos rating, votes e id.
print(f"\n3. FIRST - Primera Película Rating: {primera_pelicula['imdb']['rating']}")


# Acción 4: TAKE - Tomar primeros N elementos
primeros_5 = rdd.take(5)
print(f"\n4. TAKE - Primeras 5 Películas:")
for p in primeros_5:
    print(f"   - {p['title']}: {p['type']}")


# Acción 5: COLLECT - Traer todos los datos (usar con cuidado)
# Solo usar si el dataset es pequeño
if total_peliculas < 100:
    todos = rdd.collect()
    print(f"\n5. COLLECT - Total elementos recolectados: {len(todos)}")
else:
    print("\n5. COLLECT - Dataset muy grande, omitiendo collect()")

# Acción 5: REDUCE - Sumar todos los votos
# Convertir votos a entero. Votos està dentro de imdb
suma_votos = rdd.map(lambda row: int(row['imdb']['votes']) if row['imdb'] and row['imdb']['votes'] else 0).reduce(lambda a, b: a + b)
print(f"\n5. REDUCE - Suma total de votos: {suma_votos:,}")
# Out:
# ============================================================
# ACCIONES RDD
# ============================================================
#
# 1. COUNT - Total de Películas: 21349
#
# 2. FIRST - Primera Película Premios Ganados: 1
#
# 3. FIRST - Primera Película Rating: 6.8
#
# 4. TAKE - Primeras 5 Películas:
#    - Regeneration: movie
#    - High and Dizzy: movie
#    - Foolish Wives: movie
#    - In the Land of the Head Hunters: movie
#    - The Blue Bird: movie
#
# 5. COLLECT - Dataset muy grande, omitiendo collect()
#
# 5. REDUCE - Suma total de votos: 458,404,134

# %% [markdown]
# ## Vistas Temporales y Spark SQL
#
#
# **Spark SQL** es el módulo de Spark que permite trabajar con datos estructurados usando consultas SQL (SELECT, WHERE, GROUP BY, JOIN, etc.) sobre DataFrames. Aprovecha el optimizador Catalyst y el motor Tungsten para ejecutar consultas de forma eficiente en clúster.
#
# **¿Qué es una vista temporal?**
# Es un nombre lógico que le das a un DataFrame para poder consultarlo con SQL dentro de la misma sesión de Spark.
#
# *createOrReplaceTempView*("nombre"): crea una vista temporal de sesión (solo existe mientras esa SparkSession está viva).
#
# *createGlobalTempView*("nombre"): crea una vista global accesible desde cualquier sesión, con el catálogo global_temp (se consulta como SELECT * FROM global_temp.nombre).
#
# **¿Por qué usar vistas temporales?**
#
# - Te permiten mezclar la API de DataFrame con SQL de forma natural.
#
# - Facilitan joins y agregaciones complejas con sintaxis conocida.

# %%
#Creamos una vista temporal llamada movies_view
#Usamos la variable df que contiene la colección movies

df.createOrReplaceTempView("movies_view")
print("\nVista temporal 'movies_view' creada exitosamente")
# Out:
# Vista temporal 'movies_view' creada exitosamente

# %%
# Consulta SQL 1: Seleccionar todos los películas
print("\n--- Query 1: Todos las películas ---")
query1 = spark.sql("""
    SELECT title, year
    FROM movies_view
    LIMIT 5
""")
query1.show()
# Out:
# --- Query 1: Todos las películas ---
# +--------------------+----+
# |               title|year|
# +--------------------+----+
# |        Regeneration|1915|
# |      High and Dizzy|1920|
# |       Foolish Wives|1922|
# |In the Land of th...|1914|
# |       The Blue Bird|1918|
# +--------------------+----+

# %% [markdown]
# Cuando se cargó la colección, algunos campos numéricos fueron colocados como cadena(string). Este es el caso de Year.
#
# Hay dos formas de arreglar esto: 1) convertir (cast) cuando llamamos la sentencia SQL y crear otro DataFrame y hacer un cast sobre la columna con `withColumn`.
#
# Veamos los dos ejemplos.

# %%
# Consulta SQL 2: Películas año > 2000
print("\n--- Query 2: Películas con año > 2000 ---")
query2 = spark.sql("""
SELECT
  TRY_CAST(year AS INT) AS year_int
FROM movies_view
WHERE TRY_CAST(year AS INT) > 2000
""")
query2.show()
# Out:
# --- Query 2: Películas con año > 2000 ---
# +--------+
# |year_int|
# +--------+
# |    2001|
# |    2002|
# |    2001|
# |    2003|
# |    2002|
# |    2005|
# |    2001|
# |    2002|
# |    2001|
# |    2001|
# |    2001|
# |    2002|
# |    2005|
# |    2002|
# |    2002|
# |    2005|
# |    2001|
# |    2001|
# |    2006|
# |    2001|
# +--------+
# only showing top 20 rows

# %%
# Consulta SQL 3: Estadísticas por año
# Hice un cast porque year es string
print("\n--- Query 3: Estadísticas por año basado en el Tiempo de Duración ---")
query3 = spark.sql("""
  SELECT
    TRY_CAST(year AS INT) AS year_int,
    COUNT(*)                              AS total_peliculas,
    ROUND(AVG(runtime), 2)                AS runtime_promedio,
    MIN(runtime)                          AS runtime_minimo,
    MAX(runtime)                          AS runtime_maximo
  FROM movies_view
  WHERE TRY_CAST(year AS INT) IS NOT NULL
  GROUP BY TRY_CAST(year AS INT)
  ORDER BY year_int
""")
query3.show()
# Out:
# --- Query 3: Estadísticas por año basado en el Tiempo de Duración ---
# +--------+---------------+----------------+--------------+--------------+
# |year_int|total_peliculas|runtime_promedio|runtime_minimo|runtime_maximo|
# +--------+---------------+----------------+--------------+--------------+
# |    1896|              2|             1.0|             1|             1|
# |    1903|              1|            11.0|            11|            11|
# |    1909|              1|            14.0|            14|            14|
# |    1911|              2|             7.0|             7|             7|
# |    1913|              1|            88.0|            88|            88|
# |    1914|              3|            92.0|            12|           199|
# |    1915|              2|            75.0|            72|            78|
# |    1916|              2|            70.0|            62|            78|
# |    1917|              2|            68.5|            65|            72|
# |    1918|              1|            75.0|            75|            75|
# |    1919|              1|            22.0|            22|            22|
# |    1920|              4|            52.0|            25|            80|
# |    1921|              5|            86.0|            35|           150|
# |    1922|              3|          110.67|            72|           143|
# |    1923|              2|            70.5|            63|            78|
# |    1924|              6|           112.5|            82|           155|
# |    1925|              3|           88.33|            71|           120|
# |    1926|              6|            77.5|            58|           101|
# |    1927|              4|           129.0|            60|           240|
# |    1928|              8|            72.0|             8|           113|
# +--------+---------------+----------------+--------------+--------------+
# only showing top 20 rows

# %%
# Query 4: Películas entre 2000 y 2005
print("\n--- Query 4: Películas entre 2000 y 2005 ---")
query4 = spark.sql("""
    SELECT
        title,
        runtime,
        TRY_CAST(year AS INT) AS year_int
    FROM movies_view
    WHERE TRY_CAST(year AS INT) BETWEEN 2000 AND 2005
    ORDER BY year_int, title
""")
query4.show(10, truncate=False)
# Out:
# --- Query 4: Películas entre 2000 y 2005 ---
# +-------------------+-------+--------+
# |title              |runtime|year_int|
# +-------------------+-------+--------+
# |100 Girls          |94     |2000    |
# |102 Dalmatians     |100    |2000    |
# |2000 AD            |109    |2000    |
# |27 Missing Kisses  |98     |2000    |
# |28 Days            |103    |2000    |
# |3rd World Hero     |93     |2000    |
# |A Chinese in a Coma|108    |2000    |
# |A Dog's Will       |104    |2000    |
# |A Fish Tale        |80     |2000    |
# |A Fish Tale        |80     |2000    |
# +-------------------+-------+--------+
# only showing top 10 rows

# %%
#El campo genres que es un array en MongoDB
#en el dataframe también se convirtió en array

## Query 5: genres = Romance
print("\n--- Query 5: Género Romance ---")
query5 = spark.sql("""
  SELECT title, year, genres
  FROM movies_view
  WHERE array_contains(genres, 'Romance')
""")
query5.show(10, truncate=False)
# Out:
# --- Query 5: Género Romance ---
# +-----------------------------------+----+-----------------------------+
# |title                              |year|genres                       |
# +-----------------------------------+----+-----------------------------+
# |Wild and Woolly                    |1917|[Comedy, Western, Romance]   |
# |The Four Horsemen of the Apocalypse|1921|[Drama, Romance, War]        |
# |Clash of the Wolves                |1925|[Adventure, Romance, Western]|
# |Wings                              |1927|[Drama, Romance, War]        |
# |Robin Hood                         |1922|[Adventure, Romance, Family] |
# |A Woman of Paris: A Drama of Fate  |1923|[Drama, Romance]             |
# |Wild Oranges                       |1924|[Drama, Romance]             |
# |It                                 |1927|[Comedy, Romance]            |
# |He Who Gets Slapped                |1924|[Drama, Romance, Thriller]   |
# |Ella Cinders                       |1926|[Comedy, Romance]            |
# +-----------------------------------+----+-----------------------------+
# only showing top 10 rows

# %%
#El campo imdb que es un objeto anidado en MongoDB
#en el dataframe se convirtiò en una estructura

## Query 6: imdb
print("\n--- Query 6: IMDB ---")
query6 = spark.sql("""
  SELECT
    imdb.id                                        AS imdb_id,
    CAST(imdb.rating AS DOUBLE)                    AS rating,
    CAST(REGEXP_REPLACE(imdb.votes, '[^0-9]', '') AS INT) AS votes
  FROM movies_view
""")

query6.show(10, truncate=False)
# Out:
# --- Query 6: IMDB ---
# +-------+------+-----+
# |imdb_id|rating|votes|
# +-------+------+-----+
# |5960   |6.8   |626  |
# |11293  |7.0   |646  |
# |13140  |7.3   |1777 |
# |4150   |5.8   |223  |
# |8891   |6.6   |446  |
# |12512  |6.8   |489  |
# |832    |6.6   |1375 |
# |10146  |7.0   |639  |
# |11904  |7.0   |798  |
# |439    |7.4   |9847 |
# +-------+------+-----+
# only showing top 10 rows

# %% [markdown]
# ## Fin de la Clase
#
# ¿Cuàndo usar RDD y Spark SQL?
#
# Algunos autores argumentan que si necesitas operaciones a bajo nivel lo mejor es usar RDD.
#
# Ahora vamos a cerrar la sesión de Spark

# %%
# Cerrar Spark Session
spark.stop()
